# %%
people = {
    "name" : ["Rauf", "Arif", "Maaz", "Hadeed", "Mujahid", "Mohid"],
    "age" : [52, 51, 26, 22, 18, 17],
    "address": ["Lahore", "Karachi", "Lahore", "Islamabad", "Kakul", "Karachi"],
    "cell" : ["321-123", "320-431", "321-478", "324-446", "321-967", "320-678"],
    "bg": ["B+", "A-", "B+", "O-", "A-", "B+"]
}
people
# Out:
# {'name': ['Rauf', 'Arif', 'Maaz', 'Hadeed', 'Mujahid', 'Mohid'],
#  'age': [52, 51, 26, 22, 18, 17],
#  'address': ['Lahore', 'Karachi', 'Lahore', 'Islamabad', 'Kakul', 'Karachi'],
#  'cell': ['321-123', '320-431', '321-478', '324-446', '321-967', '320-678'],
#  'bg': ['B+', 'A-', 'B+', 'O-', 'A-', 'B+']}

# %% [markdown]
# # Loading and Displaying the Dataset:

# %%
import pandas as pd1
data = {
    'Order': [2, 3, 4, 6, 7],
    'File_Type': ['Historical', 'Historical', 'Historical', 'Historical', 'Historical'],
    'SKU_number': [1737127, 3255963, 612701, 115883, 863939],
    'SoldFlag': [0.0, 0.0, 0.0, 1.0, 1.0],
    'SoldCount': [0.0, 0.0, 0.0, 1.0, 1.0],
    'MarketingType': ['D', 'D', 'D', 'D', 'D'],
    'ReleaseNumber': [15, 7, 0, 4, 2],
    'New_Release_Flag': [1, 1, 0, 1, 1],
    'StrengthFactor': [682743.0, 1016014.0, 340464.0, 334011.0, 1287938.0],
    'PriceReg': [44.99, 24.81, 46.0, 100.0, 121.95],
    'ReleaseYear': [2015, 2005, 2013, 2006, 2010],
    'ItemCount': [8, 39, 34, 20, 28],
    'LowUserPrice': [28.97, 0.00, 30.19, 133.93, 4.00],
    'LowNetPrice': [31.84, 15.54, 27.97, 83.15, 23.99]
}

df1 = pd1.DataFrame(data)

# Display the dataset
df1.head()
print(df1)
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
from matplotlib import pyplot as plt
_df_1['SKU_number'].plot(kind='hist', bins=20, title='SKU_number')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Plot

# %%
from matplotlib import pyplot as plt
_df_6.plot(kind='scatter', x='SoldFlag', y='SoldCount', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Basic Data Analysis:

# %%
df1.describe()
# Out:
#           Order    SKU_number  SoldFlag  SoldCount  ReleaseNumber  \
# count  5.000000  5.000000e+00  5.000000   5.000000        5.00000
# mean   4.400000  1.317123e+06  0.400000   0.400000        5.60000
# std    2.073644  1.232890e+06  0.547723   0.547723        5.85662
# min    2.000000  1.158830e+05  0.000000   0.000000        0.00000
# 25%    3.000000  6.127010e+05  0.000000   0.000000        2.00000
# 50%    4.000000  8.639390e+05  0.000000   0.000000        4.00000
# 75%    6.000000  1.737127e+06  1.000000   1.000000        7.00000
# max    7.000000  3.255963e+06  1.000000   1.000000       15.00000
#
#        New_Release_Flag  StrengthFactor    PriceReg  ReleaseYear  ItemCount  \
# count          5.000000    5.000000e+00    5.000000      5.00000   5.000000
# mean           0.800000    7.322340e+05   67.550000   2009.80000  25.800000
# std            0.447214    4.194796e+05   41.268712      4.32435  12.214745
# ...

# %%
summary_stats = df1.describe()
print(summary_stats)

# Correlation matrix
correlation_matrix = df1.corr()
print(correlation_matrix)
# Out:
#           Order    SKU_number  SoldFlag  SoldCount  ReleaseNumber  \
# count  5.000000  5.000000e+00  5.000000   5.000000        5.00000
# mean   4.400000  1.317123e+06  0.400000   0.400000        5.60000
# std    2.073644  1.232890e+06  0.547723   0.547723        5.85662
# min    2.000000  1.158830e+05  0.000000   0.000000        0.00000
# 25%    3.000000  6.127010e+05  0.000000   0.000000        2.00000
# 50%    4.000000  8.639390e+05  0.000000   0.000000        4.00000
# 75%    6.000000  1.737127e+06  1.000000   1.000000        7.00000
# max    7.000000  3.255963e+06  1.000000   1.000000       15.00000
#
#        New_Release_Flag  StrengthFactor    PriceReg  ReleaseYear  ItemCount  \
# count          5.000000    5.000000e+00    5.000000      5.00000   5.000000
# mean           0.800000    7.322340e+05   67.550000   2009.80000  25.800000
# std            0.447214    4.194796e+05   41.268712      4.32435  12.214745
# ...

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

# Plotting example: PriceReg vs. LowNetPrice
plt.scatter(df1['PriceReg'], df1['LowNetPrice'])
plt.xlabel('PriceReg')
plt.ylabel('LowNetPrice')
plt.title('Scatter Plot: PriceReg vs. LowNetPrice')
plt.show()

# %% [markdown]
# # Basic Data Analysis:

# %%
# Filter rows where SoldFlag is 1
sold_items = df1[df1['SoldFlag'] == 1]
print("Sold Items:")
print(sold_items)

# Select specific columns
selected_columns = df1[['SKU_number', 'PriceReg', 'ReleaseYear']]
print("Selected Columns:")
print(selected_columns)
# Out:
# Sold Items:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 3         20        133.93        83.15
# 4         28          4.00        23.99
# Selected Columns:
#    SKU_number  PriceReg  ReleaseYear
# 0     1737127     44.99         2015
# 1     3255963     24.81         2005
# 2      612701     46.00         2013
# 3      115883    100.00         2006
# 4      863939    121.95         2010

# %% [markdown]
# # Grouping and Aggregation:

# %%
avg_price_by_marketing = df1.groupby('MarketingType')['PriceReg'].mean()
print("Average Price by MarketingType:")
print(avg_price_by_marketing)
# Out:
# Average Price by MarketingType:
# MarketingType
# D    67.55
# Name: PriceReg, dtype: float64

# %% [markdown]
# # Adding a New Column: LIST

# %%
# Calculate the total revenue for each item
print(df1['Order'])
list1= df1['Order']
print(list1)
df1['TotalRevenue'] = df1['SoldCount'] * df1['LowNetPrice']

# Display the updated DataFrame
print(df1)
# Out:
# 0    2
# 1    3
# 2    4
# 3    6
# 4    7
# Name: Order, dtype: int64
# 0    2
# 1    3
# 2    4
# 3    6
# 4    7
# Name: Order, dtype: int64
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# ...

# %% [markdown]
# # Data Cleaning:

# %%
# Remove rows with missing values
cleaned_df = df1.dropna()

# Drop a specific column
cleaned_df = cleaned_df.drop(columns=['LowUserPrice'])

# Display the cleaned DataFrame
print(cleaned_df)
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowNetPrice  TotalRevenue
# 0          8        31.84          0.00
# ...

# %% [markdown]
# # Feature Engineering:

# %%
# Create a new binary column 'HighPrice' based on 'PriceReg'
df1['HighPrice'] = df1['PriceReg'] > df1['PriceReg'].mean()

# Display the DataFrame with the new column
print(df1)
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice  TotalRevenue  HighPrice
# ...

# %%
import pandas as pd
import io

# Read the file into a Pandas DataFrame
df = pd.read_csv('/content/SalesKaggle3.csv')

# df1 = pd.read_csv('anotherfile')

# Display the first few rows of the dataframe
df.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
print(df)
# Out:
#          Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0            2  Historical     1737127       0.0        0.0             D
# 1            3  Historical     3255963       0.0        0.0             D
# 2            4  Historical      612701       0.0        0.0             D
# 3            6  Historical      115883       1.0        1.0             D
# 4            7  Historical      863939       1.0        1.0             D
# ...        ...         ...         ...       ...        ...           ...
# 198912  208023      Active      109683       NaN        NaN             D
# 198913  208024      Active      416462       NaN        NaN             D
# 198914  208025      Active      658242       NaN        NaN             S
# 198915  208026      Active     2538340       NaN        NaN             S
# 198916  208027      Active      416662       NaN        NaN             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# ...

# %%
# Specifying data types for specific columns
#df_types = {'SKU_number': 'str', 'ReleaseYear': 'int'}
#df_dtypes = pd.read_csv('/content/SalesKaggle3.csv', dtype=dtypes)
summary_stats = df.describe()
print(summary_stats)
# Out:
#                Order    SKU_number      SoldFlag     SoldCount  ReleaseNumber  \
# count  198917.000000  1.989170e+05  75996.000000  75996.000000  198917.000000
# mean   106483.543242  8.613626e+05      0.171009      0.322306       3.412202
# std     60136.716784  8.699794e+05      0.376519      1.168615       3.864243
# min         2.000000  5.000100e+04      0.000000      0.000000       0.000000
# 25%     55665.000000  2.172520e+05      0.000000      0.000000       1.000000
# 50%    108569.000000  6.122080e+05      0.000000      0.000000       2.000000
# 75%    158298.000000  9.047510e+05      0.000000      0.000000       5.000000
# max    208027.000000  3.960788e+06      1.000000     73.000000      99.000000
#
#        New_Release_Flag  StrengthFactor       PriceReg    ReleaseYear  \
# count     198917.000000    1.989170e+05  198917.000000  198917.000000
# mean           0.642248    1.117115e+06      90.895243    2006.016414
# ...

# %%
# Parsing a column as a date
df_dates = pd.read_csv('/content/SalesKaggle3.csv', parse_dates=['ReleaseYear'])
df_dates.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg ReleaseYear  \
# 0             15                 1        682743.0     44.99        2015
# 1              7                 1       1016014.0     24.81        2005
# 2              0                 0        340464.0     46.00        2013
# 3              4                 1        334011.0    100.00        2006
# 4              2                 1       1287938.0    121.95        2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
# Skipping the first 10 rows
df_skiprows = pd.read_csv('/content/SalesKaggle3.csv', skiprows=10)

# Skipping specific columns using usecols
df_usecols = pd.read_csv('/content/SalesKaggle3.csv', usecols=['SKU_number', 'SoldFlag', 'PriceReg'])
df_usecols.head()
# Out:
#    SKU_number  SoldFlag  PriceReg
# 0     1737127       0.0     44.99
# 1     3255963       0.0     24.81
# 2      612701       0.0     46.00
# 3      115883       1.0    100.00
# 4      863939       1.0    121.95

# %%
# Customizing NA values
na_values = ['NA', 'missing']
df_na = pd.read_csv('/content/SalesKaggle3.csv', na_values=na_values)
df_na.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
# Reading only the first 100 rows
df_nrows = pd.read_csv('/content/SalesKaggle3.csv', nrows=100)
df_nrows.head(100)
# Out:
#     Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0       2  Historical     1737127         0          0             D
# 1       3  Historical     3255963         0          0             D
# 2       4  Historical      612701         0          0             D
# 3       6  Historical      115883         1          1             D
# 4       7  Historical      863939         1          1             D
# ..    ...         ...         ...       ...        ...           ...
# 95    100  Historical      109306         0          0             D
# 96    101  Historical       61125         0          0             D
# 97    102  Historical      879548         1          1             D
# 98    103  Historical      632083         0          0             D
# 99    104  Historical      879991         1          1             D
#
#     ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# ...

# %%
# Setting a specific column as index
df_index_col = pd.read_csv('/content/SalesKaggle3.csv', index_col='SKU_number')

# %%
# Specifying file encoding
df_encoding = pd.read_csv('/content/SalesKaggle3.csv', encoding='utf-8')

# %%
df.shape
# Out:
# (31181, 14)

# %%
df.columns
# Out:
# Index(['Order', 'File_Type', 'SKU_number', 'SoldFlag', 'SoldCount',
#        'MarketingType', 'ReleaseNumber', 'New_Release_Flag', 'StrengthFactor',
#        'PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Order                 int64
# File_Type            object
# SKU_number          float64
# SoldFlag            float64
# SoldCount           float64
# MarketingType        object
# ReleaseNumber       float64
# New_Release_Flag    float64
# StrengthFactor      float64
# PriceReg            float64
# ReleaseYear         float64
# ItemCount           float64
# LowUserPrice        float64
# LowNetPrice         float64
# dtype: object

# %%
df.describe()
# Out:
#               Order    SKU_number      SoldFlag     SoldCount  ReleaseNumber  \
# count  31181.000000  3.118000e+04  31180.000000  31180.000000   31180.000000
# mean   15973.125269  5.964081e+05      0.257986      0.510969       4.191661
# std     9173.704925  7.058254e+05      0.437533      1.509490       3.861869
# min        2.000000  5.000200e+04      0.000000      0.000000       0.000000
# 25%     8047.000000  1.420485e+05      0.000000      0.000000       1.000000
# 50%    15979.000000  4.026855e+05      0.000000      0.000000       3.000000
# 75%    23910.000000  6.977930e+05      1.000000      1.000000       6.000000
# max    31867.000000  3.959831e+06      1.000000     73.000000      99.000000
#
#        New_Release_Flag  StrengthFactor      PriceReg   ReleaseYear  \
# count      31180.000000    3.118000e+04  31180.000000  31180.000000
# mean           0.734509    1.496914e+06    109.300651   2005.383740
# std            0.441601    1.806908e+06     84.702717      6.050817
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31181 entries, 0 to 31180
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order             31181 non-null  int64
#  1   File_Type         31181 non-null  object
#  2   SKU_number        31180 non-null  float64
#  3   SoldFlag          31180 non-null  float64
#  4   SoldCount         31180 non-null  float64
#  5   MarketingType     31180 non-null  object
#  6   ReleaseNumber     31180 non-null  float64
#  7   New_Release_Flag  31180 non-null  float64
#  8   StrengthFactor    31180 non-null  float64
#  9   PriceReg          31180 non-null  float64
#  10  ReleaseYear       31180 non-null  float64
#  11  ItemCount         31180 non-null  float64
#  12  LowUserPrice      31180 non-null  float64
#  13  LowNetPrice       31180 non-null  float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 3.3+ MB

# %%
df.nunique()
# Out:
# Order               31181
# File_Type               2
# SKU_number          31180
# SoldFlag                2
# SoldCount              35
# MarketingType           1
# ReleaseNumber          46
# New_Release_Flag        2
# StrengthFactor      30978
# PriceReg             5885
# ReleaseYear            64
# ItemCount             349
# LowUserPrice         8414
# LowNetPrice          8886
# dtype: int64

# %%
df.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical   1737127.0       0.0        0.0             D
# 1      3  Historical   3255963.0       0.0        0.0             D
# 2      4  Historical    612701.0       0.0        0.0             D
# 3      6  Historical    115883.0       1.0        1.0             D
# 4      7  Historical    863939.0       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0           15.0               1.0        682743.0     44.99       2015.0
# 1            7.0               1.0       1016014.0     24.81       2005.0
# 2            0.0               0.0        340464.0     46.00       2013.0
# 3            4.0               1.0        334011.0    100.00       2006.0
# 4            2.0               1.0       1287938.0    121.95       2010.0
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0        8.0         28.97        31.84
# ...

# %%
# df.sample(5)

# %%
df_sample_10_percent = df.sample(frac=0.5)
df_sample_10_percent.shape
# Out:
# (15590, 14)

# %%
df.isnull().sum()
# Out:
# Order               0
# File_Type           0
# SKU_number          1
# SoldFlag            1
# SoldCount           1
# MarketingType       1
# ReleaseNumber       1
# New_Release_Flag    1
# StrengthFactor      1
# PriceReg            1
# ReleaseYear         1
# ItemCount           1
# LowUserPrice        1
# LowNetPrice         1
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index                  128
# Order               249448
# File_Type           249448
# SKU_number          249448
# SoldFlag            249448
# SoldCount           249448
# MarketingType       249448
# ReleaseNumber       249448
# New_Release_Flag    249448
# StrengthFactor      249448
# PriceReg            249448
# ReleaseYear         249448
# ItemCount           249448
# LowUserPrice        249448
# LowNetPrice         249448
# dtype: int64

# %%
min_value = df['PriceReg'].min()
print(min_value)
# Out:
# 0.0

# %%
min_values = df.min()
print(min_values)
# Out:
# Order                     2
# File_Type            Histor
# SKU_number          50002.0
# SoldFlag                0.0
# SoldCount               0.0
# ReleaseNumber           0.0
# New_Release_Flag        0.0
# StrengthFactor        284.0
# PriceReg                0.0
# ReleaseYear          1935.0
# ItemCount               0.0
# LowUserPrice            0.0
# LowNetPrice             0.0
# dtype: object
# <ipython-input-22-348b6c5aa380>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   min_values = df.min()

# %%
max_value = df['PriceReg'].max()

# %%
median_value = df['PriceReg'].median()

# %%
median_value = df['PriceReg'].median()

# %%
median_value = df['PriceReg'].median()

# %%
median_values = df.median()
# Out:
# <ipython-input-27-9593fac5ed89>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median_values = df.median()

# %%
mode_value = df['PriceReg'].mode()

# %%
mode_values = df.mode()

# %%
mean_values=df.mean()
# Out:
# <ipython-input-30-6bef8202388b>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values=df.mean()
